# %%
import pandas as pd
import requests
import re
import time
from concurrent.futures import ThreadPoolExecutor
import os
import json

# %%
class SearchContent:
    def __init__(self, title, author, isbn):
        self.title = title
        self.author = author
        self.isbn = isbn

        self.description = None
        self.subjects = []
        self.num_pages = None
        self.genres = []
        self.averageRating = None

    def manage_search(self):
        self._openlib_search()
        
        for url in [self._google_url_by_isbn(), self._google_url_by_title_author()]:
            if self._is_complete():
                break
            self._google_search(url)
        #print(self._data_status())
            

    def _openlib_search(self):
        url = f"https://openlibrary.org/search.json?title={self.title}&author={self.author}"
        response = requests.get(url)
        if response.status_code != 200:
            return

        docs = response.json().get('docs', [])
        keys = {'key': "/works/", 'lending_edition_s': '/books/'}

        for doc in docs:
            if self._is_complete():
                break

            for field, prefix in keys.items():
                work_key = doc.get(field)
                if not work_key:
                    continue

                match = re.search(r'(?:/works/|/books/)?([a-zA-Z0-9]+)', work_key)
                if not match:
                    continue

                key_id = match.group(1)
                work_url = f"https://openlibrary.org{prefix}{key_id}.json"
                self._get_work_data(work_url)
                self._get_entries_data(key_id)

    def _get_work_data(self, url):
        try:
            response = requests.get(url)
            if response.status_code != 200:
                return
            data = response.json()

            if self.description is None:
                desc = data.get('description')
                if isinstance(desc, dict):
                    self.description = desc.get("value")
                elif isinstance(desc, str):
                    self.description = desc

            if not self.subjects:
                self.subjects = data.get('subjects', [])
        except Exception as e:
            print(f"Error en _get_work_data: {e}")

    def _get_entries_data(self, work_key):
        try:
            editions_url = f"https://openlibrary.org/works/{work_key}/editions.json?limit=1"
            response = requests.get(editions_url)
            if response.status_code != 200:
                return

            entries = response.json().get('entries', [])
            if not entries:
                return

            edition = entries[0]

            if self.num_pages is None:
                self.num_pages = edition.get("number_of_pages")

            if not self.genres:
                self.genres = edition.get("genres", [])
        except Exception as e:
            print(f"Error en _get_entries_data: {e}")

    def _google_url_by_isbn(self):
        return f"https://www.googleapis.com/books/v1/volumes?q=isbn:{self.isbn}"

    def _google_url_by_title_author(self):
        return f"https://www.googleapis.com/books/v1/volumes?q=intitle:{self.title}+inauthor:{self.author}"

    def _google_search(self, url):
        try:
            response = requests.get(url)
            if response.status_code != 200:
                return

            items = response.json().get("items", [])
            if not items:
                return

            for i in range(len(items)):
                volume_info = items[i].get("volumeInfo", {})
                self._fill_missing_fields_from_google(volume_info)
        except Exception as e:
            print(f"Error en _google_search: {e}")

    def _fill_missing_fields_from_google(self, info):
        if self.description is None:
            self.description = info.get("description")
        if not self.subjects:
            self.subjects = info.get("categories", [])
        if self.num_pages is None:
            self.num_pages = info.get("pageCount")
        if not self.genres:
            self.genres = info.get("categories", [])
        if not self.averageRating:
            self.averageRating = info.get("averageRating")

    def _is_complete(self):
        return (
            self.description is not None and
            self.subjects and
            self.num_pages is not None and
            self.genres
        )

    def as_dict(self):
        return {
            "title": self.title,
            "author": self.author,
            "isbn": self.isbn,
            "description": self.description,
            "subjects": self.subjects,
            "num_pages": self.num_pages,
            "genres": self.genres,
            "avgRating" : self.averageRating
        }

    def _data_status(self):
        return f"Status of {self.title}: Desc -> {self.description != None } | NumP -> {self.num_pages != None} | Subj -> {self.subjects != []} | Genr -> {self.genres != []} | Rate -> {self.averageRating != None}" 

searcher = SearchContent("The Lost World: Jurassic Park", "Don McGregor", "1852868856")
searcher.manage_search()
data = searcher.as_dict()
print(data)
# Out:
# {'title': 'The Lost World: Jurassic Park', 'author': 'Don McGregor', 'isbn': '1852868856', 'description': 'Classic Jurassic Park Volume 6 reprints the comics adaptation of the sequel to Jurassic Park, The Lost World.', 'subjects': ['Dinosaurs'], 'num_pages': 96, 'genres': ['Dinosaurs'], 'avgRating': None}

# %%
# Ejemplo de uso
column_names = ["title", "author", "year", "rating", "isbn", "url"]
df = pd.read_csv("library_for_scrapping.csv", sep=",",on_bad_lines="skip",encoding='latin-1', names = column_names)
df.head()

df_test = df.head(100)

# %%
def worker(row):
    title, author, isbn = row['title'], row['author'], row['isbn']
    searcher = SearchContent(title, author, isbn)
    searcher.manage_search()
    return searcher.as_dict()

temp_dir = os.path.join(os.getcwd(),  "temp")

batch_size = 100
total_rows = len(df)
num_batches = (total_rows + batch_size - 1) // batch_size  # redondea hacia arriba
print(num_batches)

curr_batch = 0
for i in range(curr_batch, 300):
    timeinit = time.time()

    start = i * batch_size
    end = min(start + batch_size, total_rows)
    batch_df = df.iloc[start:end]

    with ThreadPoolExecutor(max_workers=50) as executor:
        results = list(executor.map(worker, [row for _, row in batch_df.iterrows()]))

    output_filename = os.path.join(temp_dir, f"output_{i+1}.json")
    with open(output_filename, "w", encoding="utf-8") as f:
        json.dump(results, f, ensure_ascii=False, indent=2)

    timend = time.time()
    print(f"Batch {i+1}/{num_batches}, filas {start} a {end-1} | Elapsed: {timend - timeinit:.2f} s")
# Out:
# 1470
# Batch 1/1470, filas 0 a 99 | Elapsed: 110.16 s
# Batch 2/1470, filas 100 a 199 | Elapsed: 93.98 s
# Batch 3/1470, filas 200 a 299 | Elapsed: 68.13 s
# Batch 4/1470, filas 300 a 399 | Elapsed: 36.86 s
# Batch 5/1470, filas 400 a 499 | Elapsed: 31.16 s
# Batch 6/1470, filas 500 a 599 | Elapsed: 38.86 s
# Batch 7/1470, filas 600 a 699 | Elapsed: 9.28 s
# Batch 8/1470, filas 700 a 799 | Elapsed: 21.41 s
# Batch 9/1470, filas 800 a 899 | Elapsed: 108.74 s
# Batch 10/1470, filas 900 a 999 | Elapsed: 79.07 s
# Batch 11/1470, filas 1000 a 1099 | Elapsed: 89.51 s
# Batch 12/1470, filas 1100 a 1199 | Elapsed: 288.16 s
# Batch 13/1470, filas 1200 a 1299 | Elapsed: 17.67 s
# Batch 14/1470, filas 1300 a 1399 | Elapsed: 30.43 s
# Batch 15/1470, filas 1400 a 1499 | Elapsed: 118.45 s
# Batch 16/1470, filas 1500 a 1599 | Elapsed: 28.20 s
# Batch 17/1470, filas 1600 a 1699 | Elapsed: 23.64 s
# Batch 18/1470, filas 1700 a 1799 | Elapsed: 29.54 s
# Batch 19/1470, filas 1800 a 1899 | Elapsed: 27.91 s
# Batch 20/1470, filas 1900 a 1999 | Elapsed: 36.35 s
# Batch 21/1470, filas 2000 a 2099 | Elapsed: 19.10 s
# Batch 22/1470, filas 2100 a 2199 | Elapsed: 39.08 s
# Batch 23/1470, filas 2200 a 2299 | Elapsed: 180.76 s
# Batch 24/1470, filas 2300 a 2399 | Elapsed: 19.08 s
# Batch 25/1470, filas 2400 a 2499 | Elapsed: 21.12 s
# Batch 26/1470, filas 2500 a 2599 | Elapsed: 43.99 s
# Batch 27/1470, filas 2600 a 2699 | Elapsed: 121.03 s
# Batch 28/1470, filas 2700 a 2799 | Elapsed: 13.10 s
# Batch 29/1470, filas 2800 a 2899 | Elapsed: 121.68 s
# Batch 30/1470, filas 2900 a 2999 | Elapsed: 25.28 s
# Batch 31/1470, filas 3000 a 3099 | Elapsed: 28.95 s
# Batch 32/1470, filas 3100 a 3199 | Elapsed: 29.50 s
# Batch 33/1470, filas 3200 a 3299 | Elapsed: 51.69 s
# Batch 34/1470, filas 3300 a 3399 | Elapsed: 27.94 s
# Batch 35/1470, filas 3400 a 3499 | Elapsed: 16.08 s
# Batch 36/1470, filas 3500 a 3599 | Elapsed: 16.67 s
# Batch 37/1470, filas 3600 a 3699 | Elapsed: 15.78 s
# Batch 38/1470, filas 3700 a 3799 | Elapsed: 22.24 s
# Batch 39/1470, filas 3800 a 3899 | Elapsed: 15.69 s
# Batch 40/1470, filas 3900 a 3999 | Elapsed: 29.96 s
# Batch 41/1470, filas 4000 a 4099 | Elapsed: 131.77 s
# Batch 42/1470, filas 4100 a 4199 | Elapsed: 24.04 s
# Batch 43/1470, filas 4200 a 4299 | Elapsed: 28.12 s
# Batch 44/1470, filas 4300 a 4399 | Elapsed: 47.85 s
# Batch 45/1470, filas 4400 a 4499 | Elapsed: 23.85 s
# Batch 46/1470, filas 4500 a 4599 | Elapsed: 18.09 s
# Batch 47/1470, filas 4600 a 4699 | Elapsed: 32.67 s
# Batch 48/1470, filas 4700 a 4799 | Elapsed: 25.12 s
# Batch 49/1470, filas 4800 a 4899 | Elapsed: 27.76 s
# Batch 50/1470, filas 4900 a 4999 | Elapsed: 15.70 s
# Batch 51/1470, filas 5000 a 5099 | Elapsed: 17.72 s
# Batch 52/1470, filas 5100 a 5199 | Elapsed: 18.43 s
# Batch 53/1470, filas 5200 a 5299 | Elapsed: 30.51 s
# Batch 54/1470, filas 5300 a 5399 | Elapsed: 94.74 s
# Batch 55/1470, filas 5400 a 5499 | Elapsed: 26.66 s
# Batch 56/1470, filas 5500 a 5599 | Elapsed: 26.35 s
# Batch 57/1470, filas 5600 a 5699 | Elapsed: 62.86 s
# Batch 58/1470, filas 5700 a 5799 | Elapsed: 22.68 s
# Batch 59/1470, filas 5800 a 5899 | Elapsed: 25.39 s
# Batch 60/1470, filas 5900 a 5999 | Elapsed: 22.43 s
# Batch 61/1470, filas 6000 a 6099 | Elapsed: 98.10 s
# Batch 62/1470, filas 6100 a 6199 | Elapsed: 21.05 s
# Batch 63/1470, filas 6200 a 6299 | Elapsed: 79.36 s
# Batch 64/1470, filas 6300 a 6399 | Elapsed: 24.40 s
# Batch 65/1470, filas 6400 a 6499 | Elapsed: 19.72 s
# Batch 66/1470, filas 6500 a 6599 | Elapsed: 39.43 s
# Batch 67/1470, filas 6600 a 6699 | Elapsed: 23.93 s
# Batch 68/1470, filas 6700 a 6799 | Elapsed: 18.03 s
# Batch 69/1470, filas 6800 a 6899 | Elapsed: 19.98 s
# Batch 70/1470, filas 6900 a 6999 | Elapsed: 19.33 s
# Batch 71/1470, filas 7000 a 7099 | Elapsed: 16.58 s
# Batch 72/1470, filas 7100 a 7199 | Elapsed: 45.87 s
# Batch 73/1470, filas 7200 a 7299 | Elapsed: 15.22 s
# Batch 74/1470, filas 7300 a 7399 | Elapsed: 22.48 s
# Batch 75/1470, filas 7400 a 7499 | Elapsed: 26.35 s
# Batch 76/1470, filas 7500 a 7599 | Elapsed: 28.62 s
# Batch 77/1470, filas 7600 a 7699 | Elapsed: 25.77 s
# Batch 78/1470, filas 7700 a 7799 | Elapsed: 16.19 s
# Batch 79/1470, filas 7800 a 7899 | Elapsed: 41.39 s
# Batch 80/1470, filas 7900 a 7999 | Elapsed: 10.93 s
# Batch 81/1470, filas 8000 a 8099 | Elapsed: 29.85 s
# Batch 82/1470, filas 8100 a 8199 | Elapsed: 169.03 s
# Batch 83/1470, filas 8200 a 8299 | Elapsed: 15.92 s
# Batch 84/1470, filas 8300 a 8399 | Elapsed: 30.12 s
# Batch 85/1470, filas 8400 a 8499 | Elapsed: 22.93 s
# Batch 86/1470, filas 8500 a 8599 | Elapsed: 34.71 s
# Batch 87/1470, filas 8600 a 8699 | Elapsed: 23.96 s
# Batch 88/1470, filas 8700 a 8799 | Elapsed: 17.72 s
# Batch 89/1470, filas 8800 a 8899 | Elapsed: 12.66 s
# Batch 90/1470, filas 8900 a 8999 | Elapsed: 17.48 s
# Batch 91/1470, filas 9000 a 9099 | Elapsed: 19.11 s
# Batch 92/1470, filas 9100 a 9199 | Elapsed: 25.02 s
# Batch 93/1470, filas 9200 a 9299 | Elapsed: 23.76 s
# Batch 94/1470, filas 9300 a 9399 | Elapsed: 27.82 s
# Batch 95/1470, filas 9400 a 9499 | Elapsed: 29.56 s
# Batch 96/1470, filas 9500 a 9599 | Elapsed: 13.96 s
# Batch 97/1470, filas 9600 a 9699 | Elapsed: 27.85 s
# Batch 98/1470, filas 9700 a 9799 | Elapsed: 39.57 s
# Batch 99/1470, filas 9800 a 9899 | Elapsed: 31.65 s
# Batch 100/1470, filas 9900 a 9999 | Elapsed: 21.90 s
# Batch 101/1470, filas 10000 a 10099 | Elapsed: 30.84 s
# Batch 102/1470, filas 10100 a 10199 | Elapsed: 90.35 s
# Batch 103/1470, filas 10200 a 10299 | Elapsed: 39.84 s
# Batch 104/1470, filas 10300 a 10399 | Elapsed: 31.62 s
# Batch 105/1470, filas 10400 a 10499 | Elapsed: 35.71 s
# Batch 106/1470, filas 10500 a 10599 | Elapsed: 58.20 s
# Batch 107/1470, filas 10600 a 10699 | Elapsed: 34.61 s
# Batch 108/1470, filas 10700 a 10799 | Elapsed: 93.27 s
# Batch 109/1470, filas 10800 a 10899 | Elapsed: 45.98 s
# Batch 110/1470, filas 10900 a 10999 | Elapsed: 57.98 s
# Batch 111/1470, filas 11000 a 11099 | Elapsed: 60.29 s
# Batch 112/1470, filas 11100 a 11199 | Elapsed: 22.56 s
# Batch 113/1470, filas 11200 a 11299 | Elapsed: 116.87 s
# Batch 114/1470, filas 11300 a 11399 | Elapsed: 26.56 s
# Batch 115/1470, filas 11400 a 11499 | Elapsed: 23.18 s
# Batch 116/1470, filas 11500 a 11599 | Elapsed: 134.16 s
# Batch 117/1470, filas 11600 a 11699 | Elapsed: 17.58 s
# Batch 118/1470, filas 11700 a 11799 | Elapsed: 21.90 s
# Batch 119/1470, filas 11800 a 11899 | Elapsed: 28.81 s
# Batch 120/1470, filas 11900 a 11999 | Elapsed: 29.73 s
# Batch 121/1470, filas 12000 a 12099 | Elapsed: 11.32 s
# Batch 122/1470, filas 12100 a 12199 | Elapsed: 30.14 s
# Batch 123/1470, filas 12200 a 12299 | Elapsed: 31.86 s
# Batch 124/1470, filas 12300 a 12399 | Elapsed: 34.54 s
# Batch 125/1470, filas 12400 a 12499 | Elapsed: 9.58 s
# Batch 126/1470, filas 12500 a 12599 | Elapsed: 28.08 s
# Batch 127/1470, filas 12600 a 12699 | Elapsed: 117.65 s
# Batch 128/1470, filas 12700 a 12799 | Elapsed: 19.07 s
# Batch 129/1470, filas 12800 a 12899 | Elapsed: 20.73 s
# Batch 130/1470, filas 12900 a 12999 | Elapsed: 29.73 s
# Batch 131/1470, filas 13000 a 13099 | Elapsed: 26.23 s
# Batch 132/1470, filas 13100 a 13199 | Elapsed: 58.65 s
# Batch 133/1470, filas 13200 a 13299 | Elapsed: 27.56 s
# Batch 134/1470, filas 13300 a 13399 | Elapsed: 35.89 s
# Batch 135/1470, filas 13400 a 13499 | Elapsed: 26.04 s
# Batch 136/1470, filas 13500 a 13599 | Elapsed: 46.86 s
# Batch 137/1470, filas 13600 a 13699 | Elapsed: 79.59 s
# Batch 138/1470, filas 13700 a 13799 | Elapsed: 151.78 s
# Batch 139/1470, filas 13800 a 13899 | Elapsed: 157.56 s
# Batch 140/1470, filas 13900 a 13999 | Elapsed: 17.07 s
# Batch 141/1470, filas 14000 a 14099 | Elapsed: 64.33 s
# Batch 142/1470, filas 14100 a 14199 | Elapsed: 63.81 s
# Batch 143/1470, filas 14200 a 14299 | Elapsed: 55.05 s
# Batch 144/1470, filas 14300 a 14399 | Elapsed: 8.07 s
# Batch 145/1470, filas 14400 a 14499 | Elapsed: 9.68 s
# Batch 146/1470, filas 14500 a 14599 | Elapsed: 9.58 s
# Batch 147/1470, filas 14600 a 14699 | Elapsed: 13.75 s
# Batch 148/1470, filas 14700 a 14799 | Elapsed: 113.63 s
# Batch 149/1470, filas 14800 a 14899 | Elapsed: 9.88 s
# Batch 150/1470, filas 14900 a 14999 | Elapsed: 29.88 s
# Batch 151/1470, filas 15000 a 15099 | Elapsed: 23.01 s
# Batch 152/1470, filas 15100 a 15199 | Elapsed: 15.89 s
# Batch 153/1470, filas 15200 a 15299 | Elapsed: 31.12 s
# Batch 154/1470, filas 15300 a 15399 | Elapsed: 39.55 s
# Batch 155/1470, filas 15400 a 15499 | Elapsed: 23.42 s
# Batch 156/1470, filas 15500 a 15599 | Elapsed: 17.52 s
# Batch 157/1470, filas 15600 a 15699 | Elapsed: 24.65 s
# Batch 158/1470, filas 15700 a 15799 | Elapsed: 20.98 s
# Batch 159/1470, filas 15800 a 15899 | Elapsed: 35.74 s
# Batch 160/1470, filas 15900 a 15999 | Elapsed: 23.63 s
# Batch 161/1470, filas 16000 a 16099 | Elapsed: 22.02 s
# Batch 162/1470, filas 16100 a 16199 | Elapsed: 28.13 s
# Error en _get_entries_data: ('Connection aborted.', TimeoutError(10060, 'Se produjo un error durante el intento de conexión ya que la parte conectada no respondió adecuadamente tras un periodo de tiempo, o bien se produjo un error en la conexión establecida ya que el host conectado no ha podido responder', None, 10060, None))
# Batch 163/1470, filas 16200 a 16299 | Elapsed: 78.10 s
# Batch 164/1470, filas 16300 a 16399 | Elapsed: 175.64 s
# Batch 165/1470, filas 16400 a 16499 | Elapsed: 116.46 s
# Batch 166/1470, filas 16500 a 16599 | Elapsed: 37.53 s
# Batch 167/1470, filas 16600 a 16699 | Elapsed: 14.24 s
# Batch 168/1470, filas 16700 a 16799 | Elapsed: 17.46 s
# Batch 169/1470, filas 16800 a 16899 | Elapsed: 24.93 s
# Batch 170/1470, filas 16900 a 16999 | Elapsed: 23.12 s
# Batch 171/1470, filas 17000 a 17099 | Elapsed: 32.11 s
# Batch 172/1470, filas 17100 a 17199 | Elapsed: 53.27 s
# Batch 173/1470, filas 17200 a 17299 | Elapsed: 113.57 s
# Batch 174/1470, filas 17300 a 17399 | Elapsed: 155.22 s
# Batch 175/1470, filas 17400 a 17499 | Elapsed: 48.63 s
# Batch 176/1470, filas 17500 a 17599 | Elapsed: 58.85 s
# Batch 177/1470, filas 17600 a 17699 | Elapsed: 133.95 s
# Batch 178/1470, filas 17700 a 17799 | Elapsed: 136.19 s
# Batch 179/1470, filas 17800 a 17899 | Elapsed: 59.14 s
# Batch 180/1470, filas 17900 a 17999 | Elapsed: 73.97 s
# Batch 181/1470, filas 18000 a 18099 | Elapsed: 86.51 s
# Batch 182/1470, filas 18100 a 18199 | Elapsed: 31.63 s
# Batch 183/1470, filas 18200 a 18299 | Elapsed: 42.47 s
# Batch 184/1470, filas 18300 a 18399 | Elapsed: 16.65 s
# Batch 185/1470, filas 18400 a 18499 | Elapsed: 49.50 s
# Batch 186/1470, filas 18500 a 18599 | Elapsed: 34.34 s
# Batch 187/1470, filas 18600 a 18699 | Elapsed: 28.10 s
# Batch 188/1470, filas 18700 a 18799 | Elapsed: 71.53 s
# Batch 189/1470, filas 18800 a 18899 | Elapsed: 124.31 s
# Batch 190/1470, filas 18900 a 18999 | Elapsed: 50.32 s
# Batch 191/1470, filas 19000 a 19099 | Elapsed: 31.28 s
# Batch 192/1470, filas 19100 a 19199 | Elapsed: 374.32 s
# Batch 193/1470, filas 19200 a 19299 | Elapsed: 108.69 s
# Batch 194/1470, filas 19300 a 19399 | Elapsed: 54.57 s
# Batch 195/1470, filas 19400 a 19499 | Elapsed: 64.99 s
# Batch 196/1470, filas 19500 a 19599 | Elapsed: 25.75 s
# Batch 197/1470, filas 19600 a 19699 | Elapsed: 220.22 s
# Batch 198/1470, filas 19700 a 19799 | Elapsed: 252.17 s
# Batch 199/1470, filas 19800 a 19899 | Elapsed: 62.32 s
# Batch 200/1470, filas 19900 a 19999 | Elapsed: 121.93 s
# Batch 201/1470, filas 20000 a 20099 | Elapsed: 106.26 s
# Batch 202/1470, filas 20100 a 20199 | Elapsed: 185.41 s
# Batch 203/1470, filas 20200 a 20299 | Elapsed: 26.77 s
# Batch 204/1470, filas 20300 a 20399 | Elapsed: 50.83 s
# Batch 205/1470, filas 20400 a 20499 | Elapsed: 187.93 s
# Batch 206/1470, filas 20500 a 20599 | Elapsed: 210.40 s
# Batch 207/1470, filas 20600 a 20699 | Elapsed: 26.99 s
# Batch 208/1470, filas 20700 a 20799 | Elapsed: 104.54 s
# Batch 209/1470, filas 20800 a 20899 | Elapsed: 15.98 s
# Batch 210/1470, filas 20900 a 20999 | Elapsed: 22.86 s
# Batch 211/1470, filas 21000 a 21099 | Elapsed: 30.89 s
# Batch 212/1470, filas 21100 a 21199 | Elapsed: 47.82 s
# Batch 213/1470, filas 21200 a 21299 | Elapsed: 53.71 s
# Batch 214/1470, filas 21300 a 21399 | Elapsed: 68.20 s
# Batch 215/1470, filas 21400 a 21499 | Elapsed: 145.45 s
# Batch 216/1470, filas 21500 a 21599 | Elapsed: 27.59 s
# Batch 217/1470, filas 21600 a 21699 | Elapsed: 97.77 s
# Batch 218/1470, filas 21700 a 21799 | Elapsed: 51.02 s
# Batch 219/1470, filas 21800 a 21899 | Elapsed: 68.21 s
# Batch 220/1470, filas 21900 a 21999 | Elapsed: 25.59 s
# Batch 221/1470, filas 22000 a 22099 | Elapsed: 39.45 s
# Batch 222/1470, filas 22100 a 22199 | Elapsed: 103.64 s
# Batch 223/1470, filas 22200 a 22299 | Elapsed: 65.82 s
# Batch 224/1470, filas 22300 a 22399 | Elapsed: 103.68 s
# Batch 225/1470, filas 22400 a 22499 | Elapsed: 51.83 s
# Batch 226/1470, filas 22500 a 22599 | Elapsed: 103.63 s
# Batch 227/1470, filas 22600 a 22699 | Elapsed: 60.00 s
# Batch 228/1470, filas 22700 a 22799 | Elapsed: 83.21 s
# Batch 229/1470, filas 22800 a 22899 | Elapsed: 28.53 s
# Batch 230/1470, filas 22900 a 22999 | Elapsed: 21.32 s
# Batch 231/1470, filas 23000 a 23099 | Elapsed: 61.81 s
# Batch 232/1470, filas 23100 a 23199 | Elapsed: 29.08 s
# Batch 233/1470, filas 23200 a 23299 | Elapsed: 28.03 s
# Batch 234/1470, filas 23300 a 23399 | Elapsed: 32.96 s
# Batch 235/1470, filas 23400 a 23499 | Elapsed: 41.35 s
# Batch 236/1470, filas 23500 a 23599 | Elapsed: 90.71 s
# Batch 237/1470, filas 23600 a 23699 | Elapsed: 47.62 s
# Batch 238/1470, filas 23700 a 23799 | Elapsed: 33.01 s
# Batch 239/1470, filas 23800 a 23899 | Elapsed: 75.89 s
# Batch 240/1470, filas 23900 a 23999 | Elapsed: 26.04 s
# Batch 241/1470, filas 24000 a 24099 | Elapsed: 100.08 s
# Batch 242/1470, filas 24100 a 24199 | Elapsed: 42.84 s
# Batch 243/1470, filas 24200 a 24299 | Elapsed: 18.63 s
# Batch 244/1470, filas 24300 a 24399 | Elapsed: 20.34 s
# Batch 245/1470, filas 24400 a 24499 | Elapsed: 33.95 s
# Batch 246/1470, filas 24500 a 24599 | Elapsed: 20.12 s
# Batch 247/1470, filas 24600 a 24699 | Elapsed: 19.05 s
# Batch 248/1470, filas 24700 a 24799 | Elapsed: 23.31 s
# Batch 249/1470, filas 24800 a 24899 | Elapsed: 16.81 s
# Batch 250/1470, filas 24900 a 24999 | Elapsed: 25.00 s
# Batch 251/1470, filas 25000 a 25099 | Elapsed: 27.37 s
# Batch 252/1470, filas 25100 a 25199 | Elapsed: 21.38 s
# Batch 253/1470, filas 25200 a 25299 | Elapsed: 53.45 s
# Batch 254/1470, filas 25300 a 25399 | Elapsed: 40.82 s
# Batch 255/1470, filas 25400 a 25499 | Elapsed: 45.81 s
# Batch 256/1470, filas 25500 a 25599 | Elapsed: 109.22 s
# Batch 257/1470, filas 25600 a 25699 | Elapsed: 82.93 s
# Batch 258/1470, filas 25700 a 25799 | Elapsed: 40.57 s
# Batch 259/1470, filas 25800 a 25899 | Elapsed: 102.94 s
# Batch 260/1470, filas 25900 a 25999 | Elapsed: 37.64 s
# Batch 261/1470, filas 26000 a 26099 | Elapsed: 33.11 s
# Batch 262/1470, filas 26100 a 26199 | Elapsed: 27.99 s
# Batch 263/1470, filas 26200 a 26299 | Elapsed: 29.93 s
# Batch 264/1470, filas 26300 a 26399 | Elapsed: 22.73 s
# Batch 265/1470, filas 26400 a 26499 | Elapsed: 15.21 s
# Batch 266/1470, filas 26500 a 26599 | Elapsed: 11.43 s
# Batch 267/1470, filas 26600 a 26699 | Elapsed: 18.35 s
# Batch 268/1470, filas 26700 a 26799 | Elapsed: 16.79 s
# Batch 269/1470, filas 26800 a 26899 | Elapsed: 25.61 s
# Batch 270/1470, filas 26900 a 26999 | Elapsed: 73.23 s
# Batch 271/1470, filas 27000 a 27099 | Elapsed: 101.16 s
# Batch 272/1470, filas 27100 a 27199 | Elapsed: 24.64 s
# Batch 273/1470, filas 27200 a 27299 | Elapsed: 33.36 s
# Batch 274/1470, filas 27300 a 27399 | Elapsed: 14.84 s
# Batch 275/1470, filas 27400 a 27499 | Elapsed: 116.76 s
# Batch 276/1470, filas 27500 a 27599 | Elapsed: 42.43 s
# Batch 277/1470, filas 27600 a 27699 | Elapsed: 36.62 s
# Batch 278/1470, filas 27700 a 27799 | Elapsed: 24.89 s
# Batch 279/1470, filas 27800 a 27899 | Elapsed: 28.24 s
# Batch 280/1470, filas 27900 a 27999 | Elapsed: 25.00 s
# Batch 281/1470, filas 28000 a 28099 | Elapsed: 19.97 s
# Batch 282/1470, filas 28100 a 28199 | Elapsed: 23.05 s
# Batch 283/1470, filas 28200 a 28299 | Elapsed: 53.42 s
# Batch 284/1470, filas 28300 a 28399 | Elapsed: 159.16 s
# Batch 285/1470, filas 28400 a 28499 | Elapsed: 113.88 s
# Batch 286/1470, filas 28500 a 28599 | Elapsed: 101.16 s
# Batch 287/1470, filas 28600 a 28699 | Elapsed: 40.95 s
# Batch 288/1470, filas 28700 a 28799 | Elapsed: 175.52 s
# Batch 289/1470, filas 28800 a 28899 | Elapsed: 42.10 s
# Batch 290/1470, filas 28900 a 28999 | Elapsed: 37.45 s
# Batch 291/1470, filas 29000 a 29099 | Elapsed: 15.76 s
# Batch 292/1470, filas 29100 a 29199 | Elapsed: 26.43 s
# Batch 293/1470, filas 29200 a 29299 | Elapsed: 167.64 s
# Batch 294/1470, filas 29300 a 29399 | Elapsed: 15.05 s
# Batch 295/1470, filas 29400 a 29499 | Elapsed: 30.41 s
# Batch 296/1470, filas 29500 a 29599 | Elapsed: 28.68 s
# Batch 297/1470, filas 29600 a 29699 | Elapsed: 114.99 s
# Batch 298/1470, filas 29700 a 29799 | Elapsed: 80.14 s
# Batch 299/1470, filas 29800 a 29899 | Elapsed: 23.56 s
# Batch 300/1470, filas 29900 a 29999 | Elapsed: 18.73 s
